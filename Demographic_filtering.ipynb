# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data1=pd.read_csv('dataset/tmdb_5000_credits.csv')
data2=pd.read_csv('dataset/tmdb_5000_movies.csv')

# %%
data1.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# ...

# %%
data2.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
columns=['id','title','cast','crew']
data1.columns=columns
data2=data2.merge(data1,on='id')

# %%
data2.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
c=data2['vote_average'].mean()

# %%
c
# Out:
# 6.092171559442011

# %%
m=data2['vote_count'].quantile(0.9)
m
# Out:
# 1838.4000000000015

# %%
copy=data2.copy()
q_movies=copy[copy['vote_count']>=m]

# %%
q_movies.shape
# Out:
# (481, 23)

# %%
def weighted_rating(data2,m=m,C=c):
    v=data2['vote_count']
    R=data2['vote_average']
    return(v/(v+m)*R)+(m/(m+c)*c)

# %%
q_movies['score']=q_movies.apply(weighted_rating,axis=1)

# %%
q_movies = q_movies.sort_values('score', ascending=False)
q_movies[['title_x', 'vote_count', 'vote_average', 'score']].head(10)
# Out:
#                                                 title_x  vote_count  \
# 96                                            Inception       13752
# 65                                      The Dark Knight       12002
# 1881                           The Shawshank Redemption        8205
# 662                                          Fight Club        9413
# 95                                         Interstellar       10867
# 3232                                       Pulp Fiction        8428
# 809                                        Forrest Gump        7927
# 94                              Guardians of the Galaxy        9742
# 262   The Lord of the Rings: The Fellowship of the Ring        8705
# 287                                    Django Unchained       10099
#
#       vote_average      score
# 96             8.1  13.216908
# 65             8.2  13.182856
# 1881           8.5  13.016162
# 662            8.3  13.015888
# 95             8.1  13.000025
# 3232           8.3  12.885772
# ...

# %%
popu=data2.sort_values('popularity',ascending=False)
plt.figure(figsize=(12,6))
plt.barh(popu['title_x'].head(),popu['popularity'].head(),align='center')
plt.gca().invert_yaxis()
